# %%
print("Welcome to your simple Quiz chatbot")
print("answer the questions by typing a, b, c or d\n")
score=0
questions =[
    {
        "Question": "1. How many continents are there in the world?",
        "a": "5",
        "b": "6",
        "c": "7",
        "d": "8",
        "Answer": "c"
    },
    {
        "Question": "2. Which is the largest ocean on Earth?",
        "a": "Atlantic Ocean",
        "b": "Indian Ocean",
        "c": "Pacific Ocean",
        "d": "Arctic Ocean",
        "Answer": "c"
    },
    {
        "Question": "3. Who discovered gravity?",
        "a": "Albert Einstein",
        "b": "Isaac Newton",
        "c": "Galileo Galilei",
        "d": "Nikola Tesla",
        "Answer": "b"
    },
    {
        "Question": "4. Which is the longest river in the world?",
        "a": "Amazon River",
        "b": "Nile River",
        "c": "Yangtze River",
        "d": "Mississippi River",
        "Answer": "b"
    },
    {
        "Question": "5. What is the capital of Japan?",
        "a": "Osaka",
        "b": "Tokyo",
        "c": "Kyoto",
        "d": "Nagoya",
        "Answer": "b"
    },
    {
        "Question": "6. Which planet is known as the Blue Planet?",
        "a": "Mars",
        "b": "Earth",
        "c": "Neptune",
        "d": "Venus",
        "Answer": "b"
    },
    {
        "Question": "7. What is the largest mammal?",
        "a": "African Elephant",
        "b": "Blue Whale",
        "c": "Giraffe",
        "d": "Hippopotamus",
        "Answer": "b"
    },
    {
        "Question": "8. Which gas do plants absorb from the atmosphere?",
        "a": "Oxygen",
        "b": "Hydrogen",
        "c": "Carbon Dioxide",
        "d": "Nitrogen",
        "Answer": "c"
    },
    {
        "Question": "9. Which country is known as the Land of the Pyramids?",
        "a": "Mexico",
        "b": "Sudan",
        "c": "Egypt",
        "d": "Iraq",
        "Answer": "c"
    },
    {
        "Question": "10. What is the freezing point of water?",
        "a": "0°C",
        "b": "10°C",
        "c": "5°C",
        "d": "20°C",
        "Answer": "a"
    }
]

for q in questions:
    print(q["Question"])
    print("a)",q["a"])
    print("b)",q["b"])
    print("c)",q["c"])
    print("d)",q["d"])
    
    user_ans=input("your answer: ").lower()

    if user_ans==q["answer"]:
        print("correct\n")
        score+=1
    else:
        print("wrong: correct answer is : ",q["answer"],"\n")
print("your final score=",score,"/",len(quertion))
# Out:
# Welcome to your simple Quiz chatbot
# answer the questions by typing a, b, c or d
#
# 1. How many continents are there in the world?
# a) 5
# b) 6
# c) 7
# d) 8
